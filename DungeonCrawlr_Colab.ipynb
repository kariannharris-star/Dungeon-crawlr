# %% [markdown]
# # Dungeon Crawlr
# A text-based dungeon adventure game
#
# Run the cells below to set up and play!

# %%
# Mount Google Drive (optional - for saving games)
from google.colab import drive
drive.mount('/content/drive')

# %%
# Clone the game from GitHub
# !git clone https://github.com/kariannharris-star/Dungeon-crawlr.git
# %cd Dungeon-crawlr

# %%
# Copy to Google Drive (so you keep it permanently)
# !cp -r /content/Dungeon-crawlr /content/drive/MyDrive/Dungeon-crawlr
print("Game copied to Google Drive!")

# %%
# Run the game (Note: text input works differently in Colab)
# For best experience, download and run locally
# !python run_game.py
